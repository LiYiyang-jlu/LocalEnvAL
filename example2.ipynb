# %%
# Data save bat
import struct
import LocalEnvAL as le
import os

from LocalEnvAL.LEF import SLEF
def path_read(dir: str) -> list:
    files = os.listdir(dir)
    struct_list = list(map(le.Structure.from_file, 
                           [ os.path.join(dir,file) for file in files 
                            if not os.path.isdir(os.path.join(dir, file))]))

    return struct_list

path = "./TestStructure/Si"
struct_list = path_read(path)
slef_list = list(map(le.SLEF, struct_list ))

for stct in slef_list:
    le.SLEF_save(stct)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 16
#      13     return struct_list
#      15 path = "TestStructure/Si"
# ---> 16 struct_list = path_read(path)
#      17 slef_list = list(map(le.SLEF, struct_list ))
#      19 for stct in slef_list:
#
# Cell In[2], line 8, in path_read(dir)
#       7 def path_read(dir: str) -> list:
# ----> 8     files = os.listdir(dir)
#       9     struct_list = list(map(le.Structure.from_file,
#      10                            [ os.path.join(dir,file) for file in files
#      11                             if not os.path.isdir(os.path.join(dir, file))]))
#      13     return struct_list
#
# FileNotFoundError: [Errno 2] No such file or directory: 'TestStructure/Si'
